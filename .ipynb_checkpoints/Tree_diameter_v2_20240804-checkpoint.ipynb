# %% [markdown]
# # Load packages

# %%
# ! pip install supervision
# ! pip install -q supervision==0.6.0
# ! pip install contextily
# ! pip install scikit-image
# ! pip install pykrige
# ! pip install selenium

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\USER\.conda\envs\geo\python.exe

# %%
# import matplotlib.patches as patches
import supervision as sv

import sys
import numpy as np
import glob
import os
import bz2
import pandas as pd
import geopandas as gpd
import pickle
from PIL import Image
import street_triangulation as tri
import supervision as sv
import cv2
import math
import pdb
import contextily as ctx
from matplotlib.colors import ListedColormap
import matplotlib.patches as patches
import matplotlib.pyplot as plt



pd.set_option('display.max_columns', None)

# sys.path.append(r'E:\Research\StreetView\gsv_pano')
sys.path.append(r'D:\Research\StreetView\gsv_pano')

from pano import GSV_pano
import utils

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Set directories

# %%
detect_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
depthmap_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_depth'
image_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail'
pano_meta_fname = r"D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail.csv"
annotated_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
local_crs = 6569 # EPSG:6569, NAD83(2011) / South Carolina
save_dir = r'D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_trunks'

# detect_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
# depthmap_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_depth'
# image_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail'
# pano_meta_fname = r"E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail.csv"
# annotated_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
# local_crs = 6569 # EPSG:6569, NAD83(2011) / South Carolina
# save_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_trunks'

# %%
img_height = 768
img_width = 1024

camera_dis_thres =  30  #20
trunk_near_thres = 3

# state colleage
# detect_dir = r'G:\My Drive\Research\street_mapping\thumbnals_state_college'
# depthmap_dir = r'G:\My Drive\Research\street_mapping\thumbnals_state_college\depthmaps'
# image_dir = r'G:\My Drive\Research\street_mapping\thumbnals_state_college'
# pano_meta_fname = r"G:\My Drive\Research\street_mapping\state_college_json\jsons.csv"
# annotated_dir = r'G:\My Drive\Research\street_mapping\thumbnals_state_college'
# local_crs = 6562 # EPSG:6562, NAD83(2011) / Pennsylvania North

# save_dir = r'G:\My Drive\Research\street_mapping\state_college_trunks'
# os.makedirs(save_dir, exist_ok=True)
# CLASSES = ['vehicle', 'tree_trunk', 'person', 'sidewalk', 'road', 'building', 'grass']   # , 'tree root collar'
# trunk_index = 1


# Columbia
# detect_dir = r'G:\My Drive\Research\street_mapping\South_Harden_St\South_Harden_St_segmented'
# depthmap_dir = r'G:\My Drive\Research\street_mapping\South_Harden_St\thumbnails\depthmaps'
# image_dir = r'D:\Research\street_image_mapping\South_Harden_St\thumbnails'
# pano_meta_fname = r"G:\My Drive\Research\street_mapping\South_Harden_St\thumbnails.csv"
# annotated_dir = r'G:\My Drive\Research\street_mapping\South_Harden_St\South_Harden_St_segmented'
# local_crs = 6569 # EPSG:6569, NAD83(2011) / South Carolina
# save_dir = r'G:\My Drive\Research\street_mapping\South_Harden_St\trunks'

# detect_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
# depthmap_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_depth'
# image_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail'
# pano_meta_fname = r"E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail.csv"
# annotated_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented'
# local_crs = 6569 # EPSG:6569, NAD83(2011) / South Carolina
# save_dir = r'E:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_trunks'



os.makedirs(save_dir, exist_ok=True)


CLASSES = ['tree_trunk']   # , 'tree root collar'
trunk_index = 0

# %%
pano_meta_df = pd.read_csv(pano_meta_fname).set_index('panoId')
pano_meta_df
# Out:
#                         image_width  image_height  tile_width  tile_height  \
# panoId
# znuYMYuRAnWodO_nKEcpAw        13312          6656         512          512
# bD0H1wJkNsf920LkpU9bXA        16384          8192         512          512
# p4RFDXvkNmC42i42QrU10Q        16384          8192         512          512
# HLEanEQavzLGOgt1CAy8tA        16384          8192         512          512
# ye0Bj3kdK30YplYkpneKdQ        16384          8192         512          512
# ...                             ...           ...         ...          ...
# 64nVR_sX79QOPrzaB4geGA        16384          8192         512          512
# wccJ8OQ4GUVc_wiXBd8FgA        16384          8192         512          512
# iwIR7ReTsovIl2NEO1n1jA        16384          8192         512          512
# kC_WDnM37rYXWVuZEQoTWQ        16384          8192         512          512
# SQUhdoa-M1lx7seRSAG7LQ        16384          8192         512          512
#
#                        image_date  imagery_type projection_type  pano_yaw_deg  \
# panoId
# znuYMYuRAnWodO_nKEcpAw     2014-8             1       spherical      5.234205
# bD0H1wJkNsf920LkpU9bXA     2022-2             1       spherical    183.540970
# p4RFDXvkNmC42i42QrU10Q     2022-2             1       spherical    183.230072
# HLEanEQavzLGOgt1CAy8tA    2021-12             1       spherical    184.593185
# ye0Bj3kdK30YplYkpneKdQ     2022-2             1       spherical    183.486938
# ...                           ...           ...             ...           ...
# 64nVR_sX79QOPrzaB4geGA     2022-2             1       spherical    186.775589
# wccJ8OQ4GUVc_wiXBd8FgA     2022-2             1       spherical    189.261673
# iwIR7ReTsovIl2NEO1n1jA     2022-2             1       spherical    184.167801
# kC_WDnM37rYXWVuZEQoTWQ     2022-2             1       spherical    184.148117
# SQUhdoa-M1lx7seRSAG7LQ     2022-2             1       spherical      2.533683
#
#                         tilt_yaw_deg  tilt_pitch_deg  zoomLevels        lat  \
# panoId
# znuYMYuRAnWodO_nKEcpAw     90.486496        1.345668         NaN  33.990883
# bD0H1wJkNsf920LkpU9bXA     88.687180        0.508491         NaN  33.990815
# p4RFDXvkNmC42i42QrU10Q     89.076469        0.397373         NaN  33.990722
# HLEanEQavzLGOgt1CAy8tA     89.518768        1.281742         NaN  33.990650
# ye0Bj3kdK30YplYkpneKdQ     88.766350        0.703531         NaN  33.990631
# ...                              ...             ...         ...        ...
# 64nVR_sX79QOPrzaB4geGA     89.057243        0.207718         NaN  33.991285
# wccJ8OQ4GUVc_wiXBd8FgA     89.076744      359.052429         NaN  33.991405
# iwIR7ReTsovIl2NEO1n1jA     89.896645      359.674896         NaN  33.990953
# kC_WDnM37rYXWVuZEQoTWQ     89.817009        1.266670         NaN  33.991041
# SQUhdoa-M1lx7seRSAG7LQ     89.680550      359.927490         NaN  33.991136
#
#                               lng  original_lat  original_lng  \
# panoId
# znuYMYuRAnWodO_nKEcpAw -81.006261           NaN           NaN
# bD0H1wJkNsf920LkpU9bXA -81.006311           NaN           NaN
# p4RFDXvkNmC42i42QrU10Q -81.006318           NaN           NaN
# HLEanEQavzLGOgt1CAy8tA -81.006327           NaN           NaN
# ye0Bj3kdK30YplYkpneKdQ -81.006325           NaN           NaN
# ...                           ...           ...           ...
# 64nVR_sX79QOPrzaB4geGA -81.010097           NaN           NaN
# wccJ8OQ4GUVc_wiXBd8FgA -81.010068           NaN           NaN
# iwIR7ReTsovIl2NEO1n1jA -81.006299           NaN           NaN
# kC_WDnM37rYXWVuZEQoTWQ -81.006291           NaN           NaN
# SQUhdoa-M1lx7seRSAG7LQ -81.006253           NaN           NaN
#
#                         elevation_wgs84_m       description  streetRange  \
# panoId
# znuYMYuRAnWodO_nKEcpAw                NaN  101 S Woodrow St          NaN
# bD0H1wJkNsf920LkpU9bXA                NaN  101 S Woodrow St          NaN
# p4RFDXvkNmC42i42QrU10Q                NaN  100 S Woodrow St          NaN
# HLEanEQavzLGOgt1CAy8tA                NaN  100 S Woodrow St          NaN
# ye0Bj3kdK30YplYkpneKdQ                NaN  100 S Woodrow St          NaN
# ...                                   ...               ...          ...
# 64nVR_sX79QOPrzaB4geGA                NaN      101 Queen St          NaN
# wccJ8OQ4GUVc_wiXBd8FgA                NaN      103 Queen St          NaN
# iwIR7ReTsovIl2NEO1n1jA                NaN    101 Woodrow St          NaN
# kC_WDnM37rYXWVuZEQoTWQ                NaN    101 Woodrow St          NaN
# SQUhdoa-M1lx7seRSAG7LQ                NaN    100 Woodrow St          NaN
#
#                                           region country  elevation_egm96_m  \
# panoId
# znuYMYuRAnWodO_nKEcpAw  Columbia; South Carolina      US          89.712708
# bD0H1wJkNsf920LkpU9bXA  Columbia; South Carolina      US          89.003746
# p4RFDXvkNmC42i42QrU10Q  Columbia; South Carolina      US          88.850060
# HLEanEQavzLGOgt1CAy8tA  Columbia; South Carolina      US          88.781258
# ye0Bj3kdK30YplYkpneKdQ  Columbia; South Carolina      US          88.756538
# ...                                          ...     ...                ...
# 64nVR_sX79QOPrzaB4geGA  Columbia; South Carolina      US          89.012497
# wccJ8OQ4GUVc_wiXBd8FgA  Columbia; South Carolina      US          89.108795
# iwIR7ReTsovIl2NEO1n1jA  Columbia; South Carolina      US          89.126038
# kC_WDnM37rYXWVuZEQoTWQ  Columbia; South Carolina      US          89.020790
# SQUhdoa-M1lx7seRSAG7LQ  Columbia; South Carolina      US          89.044853
#
#                         links_cnt  link_forward_yawDeg  \
# panoId
# znuYMYuRAnWodO_nKEcpAw          4             4.480649
# bD0H1wJkNsf920LkpU9bXA          2           184.599854
# p4RFDXvkNmC42i42QrU10Q          2           184.667160
# HLEanEQavzLGOgt1CAy8tA          2           184.638870
# ye0Bj3kdK30YplYkpneKdQ          2           184.591965
# ...                           ...                  ...
# 64nVR_sX79QOPrzaB4geGA          2           184.367188
# wccJ8OQ4GUVc_wiXBd8FgA          2           184.360657
# iwIR7ReTsovIl2NEO1n1jA          2           184.480652
# kC_WDnM37rYXWVuZEQoTWQ          2           184.475540
# SQUhdoa-M1lx7seRSAG7LQ          2             4.495994
#
#                                  link_f_panoId  link_f_road_argb  \
# panoId
# znuYMYuRAnWodO_nKEcpAw  iwIR7ReTsovIl2NEO1n1jA               NaN
# bD0H1wJkNsf920LkpU9bXA  p4RFDXvkNmC42i42QrU10Q               NaN
# p4RFDXvkNmC42i42QrU10Q  HLEanEQavzLGOgt1CAy8tA               NaN
# HLEanEQavzLGOgt1CAy8tA  ye0Bj3kdK30YplYkpneKdQ               NaN
# ye0Bj3kdK30YplYkpneKdQ  o3bXwz6__nb8XqfLceHOxA               NaN
# ...                                        ...               ...
# 64nVR_sX79QOPrzaB4geGA  3KcssIfHMS2dkud-EWFGvw               NaN
# wccJ8OQ4GUVc_wiXBd8FgA  64nVR_sX79QOPrzaB4geGA               NaN
# iwIR7ReTsovIl2NEO1n1jA  znuYMYuRAnWodO_nKEcpAw               NaN
# kC_WDnM37rYXWVuZEQoTWQ  iwIR7ReTsovIl2NEO1n1jA               NaN
# SQUhdoa-M1lx7seRSAG7LQ  VAEV-pBaIoOc-a5y37GYWw               NaN
#
#                        link_f_description  link_backward_yawDeg  \
# panoId
# znuYMYuRAnWodO_nKEcpAw         Woodrow St            279.834473
# bD0H1wJkNsf920LkpU9bXA       S Woodrow St              4.619255
# p4RFDXvkNmC42i42QrU10Q       S Woodrow St              4.599847
# HLEanEQavzLGOgt1CAy8tA       S Woodrow St              4.667163
# ye0Bj3kdK30YplYkpneKdQ       S Woodrow St              4.638868
# ...                                   ...                   ...
# 64nVR_sX79QOPrzaB4geGA           Queen St              4.360662
# wccJ8OQ4GUVc_wiXBd8FgA           Queen St              4.336567
# iwIR7ReTsovIl2NEO1n1jA       S Woodrow St              4.475543
# kC_WDnM37rYXWVuZEQoTWQ         Woodrow St              4.490815
# SQUhdoa-M1lx7seRSAG7LQ         Woodrow St            184.490814
#
#                                  link_b_panoId  link_b_road_argb  \
# panoId
# znuYMYuRAnWodO_nKEcpAw  oUNvMa7PVtjhDnx-1NnsTQ               NaN
# bD0H1wJkNsf920LkpU9bXA  znuYMYuRAnWodO_nKEcpAw               NaN
# p4RFDXvkNmC42i42QrU10Q  bD0H1wJkNsf920LkpU9bXA               NaN
# HLEanEQavzLGOgt1CAy8tA  p4RFDXvkNmC42i42QrU10Q               NaN
# ye0Bj3kdK30YplYkpneKdQ  HLEanEQavzLGOgt1CAy8tA               NaN
# ...                                        ...               ...
# 64nVR_sX79QOPrzaB4geGA  wccJ8OQ4GUVc_wiXBd8FgA               NaN
# wccJ8OQ4GUVc_wiXBd8FgA  skKFC4dwbevwx7Jid_sn9g               NaN
# iwIR7ReTsovIl2NEO1n1jA  kC_WDnM37rYXWVuZEQoTWQ               NaN
# kC_WDnM37rYXWVuZEQoTWQ  SQUhdoa-M1lx7seRSAG7LQ               NaN
# SQUhdoa-M1lx7seRSAG7LQ  kC_WDnM37rYXWVuZEQoTWQ               NaN
#
#                        link_b_description  \
# panoId
# znuYMYuRAnWodO_nKEcpAw         Heyward St
# bD0H1wJkNsf920LkpU9bXA       S Woodrow St
# p4RFDXvkNmC42i42QrU10Q       S Woodrow St
# HLEanEQavzLGOgt1CAy8tA       S Woodrow St
# ye0Bj3kdK30YplYkpneKdQ       S Woodrow St
# ...                                   ...
# 64nVR_sX79QOPrzaB4geGA           Queen St
# wccJ8OQ4GUVc_wiXBd8FgA           Queen St
# iwIR7ReTsovIl2NEO1n1jA         Woodrow St
# kC_WDnM37rYXWVuZEQoTWQ         Woodrow St
# SQUhdoa-M1lx7seRSAG7LQ         Woodrow St
#
#                                                               link_others
# panoId
# znuYMYuRAnWodO_nKEcpAw  89.1512451171875|_dSD7M9ggy25Y8ocd3bOVw||Heywa...
# bD0H1wJkNsf920LkpU9bXA                                                NaN
# p4RFDXvkNmC42i42QrU10Q                                                NaN
# HLEanEQavzLGOgt1CAy8tA                                                NaN
# ye0Bj3kdK30YplYkpneKdQ                                                NaN
# ...                                                                   ...
# 64nVR_sX79QOPrzaB4geGA                                                NaN
# wccJ8OQ4GUVc_wiXBd8FgA                                                NaN
# iwIR7ReTsovIl2NEO1n1jA                                                NaN
# kC_WDnM37rYXWVuZEQoTWQ                                                NaN
# SQUhdoa-M1lx7seRSAG7LQ                                                NaN
#
# [127 rows x 31 columns]

# %%
detect_files = glob.glob(os.path.join(detect_dir, "*.bz2"))
detect_files = sorted(detect_files)
print("Found file count:", len(detect_files))
# ['D:\\OneDrive_PSU\\OneDrive - The Pennsylvania State University\\Research_doc\\street_image_mapping\\Heyward_st_pano_thumnail_segmented\\piIyY_Bgq2dmllHQlN7FRw_0.0_0.0_0_226.73_R135.pkl.bz2']
# detect_files = ['D:\\OneDrive_PSU\\OneDrive - The Pennsylvania State University\\Research_doc\\street_image_mapping\\Heyward_st_pano_thumnail_segmented\\piIyY_Bgq2dmllHQlN7FRw_0.0_0.0_0_226.73_R135.pkl.bz2', 'D:\\OneDrive_PSU\\OneDrive - The Pennsylvania State University\\Research_doc\\street_image_mapping\\Heyward_st_pano_thumnail_segmented\\XShHFvEc3Mi2fhPmjY7OGw_0.0_0.0_0_180.97_R90.pkl.bz2'] + detect_files  # add a file on the top for testing
# detect_files
detect_files = ['D:\\OneDrive_PSU\\OneDrive - The Pennsylvania State University\\Research_doc\\street_image_mapping\\Heyward_st_pano_thumnail_segmented\\L9Jp_XEhrMmgm35YhruiRQ_0.0_0.0_0_273.58_R90.pkl.bz2'] + detect_files  # add a file on the top for testing


print("Found file count:", len(detect_files))
# Out:
# Found file count: 762
# Found file count: 763

# %%
# detect_files[458:]  # detect_files[458] = XShHFvEc3Mi2fhPmjY7OGw_0.0_0.0_0_180.97_R90.pkl.bz2

# %% [markdown]
# # Compute measurement location

# %%
pair_trunk_df_list = []

for idx, detect_file in enumerate(detect_files[:]): # 458:460
    try:
        # print("detect_file: ", detect_file)
        # detect_file = os.path.join(detect_dir, r'l-PhEd7ACdyR12n08p1Q0Q_0.0_0.0_0_33.59_R90.pkl.bz2')  # [68:69]
        # detect_file = os.path.join(detect_dir, r'XciMXMjYPg0jhKh8cKG1eA_0.0_0.0_0_78.39_R135.pkl.bz2')
        # detect_file = os.path.join(detect_dir, r'vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2')
        
        gdf_list = []

        basename = os.path.basename(detect_file).replace('.pkl.bz2', '.jpg')
        direction_str = basename.replace(".pkl.bz2", "").split("_")[-1]

        image_fname = os.path.join(image_dir, basename)

        
        # Step 1: form image pairs. 1) select a non-look behind direction. 2) 
        # non-look behind direction: R90, R45, L90, L45.
        # look behind direction:     L135, R135. 

        # skip the look behind image
        if direction_str in ['L135', 'R135']:  #  I make a mistake when naming the thumbnails in State College: the "L135" and "L45" should be switched.
            print("skip: ", direction_str, basename)
 
        print(f"Processing: {idx + 1} / {len(detect_files)}: {basename}" )


        # find image pairs
        panoID = basename[:22]
        pano_meta = pano_meta_df.loc[panoID]
        # print("pano_meta:", pano_meta)

        # obtain image pairs: R90 <-> R135, R45 <-> R90, L90 <-> L135, L45 <-> L90, 
        image_pairs = tri.form_image_pairs(detect_file, pano_meta, detect_dir=None)
        # print("idx:", idx)


        if len(image_pairs) == 0:
            print("    No image_pairs, skip. \n")
            continue

        else:
            for img1, img2 in image_pairs:
                print(f"    image pairs: {os.path.basename(img1), os.path.basename(img2)}")

        print()
        # print("idx:", idx)

        # extract the trunks in the current image
        trunk_df = tri.get_trunks_in_an_image(detect_file, trunk_index, image_dir, pano_meta_df, depthmap_dir, local_crs)
        # print("trunk_df:", trunk_df)
        # print("idx:", idx, trunk_df)  # passed

        # Step 2:  form trunk pairs
        # extract the trunks in the paire image
        for pair in image_pairs:
            print("pair[1]:", pair[1])
            paired_trunk_df = tri.get_trunks_in_an_image(pair[1], trunk_index, image_dir, pano_meta_df, depthmap_dir, local_crs)
            # print("paired_trunk_df:", paired_trunk_df)  

            # merge trunks into a GeoDataFrame
            all_gdf = tri.merge_trunk_df_pair(trunk_df, paired_trunk_df, local_crs)
            # print("all_gdf:", all_gdf)
    
            all_trunk_gdf = all_gdf.query("Type == 'trunk' ")
            # all_trunk_gdf['depth_x'] = all_trunk_gdf['depth_x'].astype('float')
            # all_trunk_gdf['depth_y'] = all_trunk_gdf['depth_y'].astype('float')
            all_trunk_gdf = all_trunk_gdf.reset_index()
    
            # all_camera_gdf = all_gdf.query("Type == 'camera' ")
            # print("all_camera_gdf:", all_camera_gdf)
    
            # form trunck pairs
            trunk_pairs_df = tri.form_trunk_pairs(all_trunk_gdf, near_thres=trunk_near_thres, camera_dis_thres=camera_dis_thres)
    
            if trunk_pairs_df is None:
                print("    No trunk pairs.")
                continue
    
            # print("trunk_pairs_df:", trunk_pairs_df)
    
            pair_cnt = int(len(trunk_pairs_df) / 2)
    
            # print("all_trunk_gdf:", all_trunk_gdf)
    
            # draw the trunks
            for p in range(pair_cnt):
                a_pair_trunk_df = trunk_pairs_df.iloc[2 * p:2 * p + 2].copy()
                a_pair_trunk_df = tri.triangulate_trunk_location(a_pair_trunk_df)  # compute location
                a_pair_trunk_df = tri.compute_diameter(a_pair_trunk_df)  # compute diameters
    
                pair_trunk_df_list.append(a_pair_trunk_df)
    
                tri.show_detailed_images(a_pair_trunk_df, local_crs, image_dir, annotated_dir, save_dir)
    
            print()
            # break

    except Exception as e:
        print()
        print("Error:", e, idx, basename)
        print()
        # break

all_pair_trunk_df = pd.concat(pair_trunk_df_list)
csv_fname = os.path.join(save_dir, "detected_trunks.csv")
all_pair_trunk_df.to_csv(csv_fname, index=False)

geometry = gpd.points_from_xy(all_pair_trunk_df['tri_x'], all_pair_trunk_df['tri_y'])
localized_trunk_gdf = gpd.GeoDataFrame(data=all_pair_trunk_df, geometry=geometry).set_crs(local_crs)
localized_trunk_fname = os.path.join(save_dir, "localized_trunks.shp")
localized_trunk_gdf.to_file(localized_trunk_fname)
# Out:
# Processing: 1 / 763: vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.jpg
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2')
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.pkl.bz2')
#
# pair[1]: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented\Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2
# C:\Users\USER\.conda\envs\geo\lib\site-packages\contextily\tile.py:614: UserWarning: The inferred zoom level of 20 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)
# pair[1]: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented\Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.pkl.bz2
#     No trunk pairs.
# Processing: 2 / 763: vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.jpg
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2')
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.pkl.bz2')
#
# pair[1]: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented\Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2
# C:\Users\USER\.conda\envs\geo\lib\site-packages\contextily\tile.py:614: UserWarning: The inferred zoom level of 20 is not valid for the current tile provider (valid zooms: 0 - 19).
#   warnings.warn(msg)
# pair[1]: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented\Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.pkl.bz2
#     No trunk pairs.
# Processing: 3 / 763: vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.jpg
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2')
#     image pairs: ('vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.pkl.bz2', 'Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.pkl.bz2')
#
# pair[1]: D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Heyward_st_pano_thumnail_segmented\Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_318.76_L135.pkl.bz2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 59
#      57 for pair in image_pairs:
#      58     print("pair[1]:", pair[1])
# ---> 59     paired_trunk_df = tri.get_trunks_in_an_image(pair[1], trunk_index, image_dir, pano_meta_df, depthmap_dir, local_crs)
#      60     # print("paired_trunk_df:", paired_trunk_df)
#      61
#      62     # merge trunks into a GeoDataFrame
#      63     all_gdf = tri.merge_trunk_df_pair(trunk_df, paired_trunk_df, local_crs)
#
# File D:\OneDrive_PSU\OneDrive - The Pennsylvania State University\Research_doc\street_image_mapping\Python_code\street_triangulation.py:284, in get_trunks_in_an_image(detect_file, trunk_class_id, image_dir, pano_meta_df, depthmap_dir, local_crs)
#     280 heading_rad = heading_deg / 180 * np.pi
#     282 panoID = basename[:22]
# --> 284 pano_obj = GSV_pano(panoId=panoID, crs_local=local_crs)
#     287 direction_str = basename.replace(".pkl.bz2", "").split("_")[-1]
#     290 # print("get_trunks_in_an_image(): direction_str:", direction_str)  # passed
#
# File D:\Research\StreetView\gsv_pano\pano.py:152, in GSV_pano.__init__(self, panoId, json_file, request_lon, request_lat, request_address, crs_local, saved_path)
#     148 try:
#     150     if (self.panoId != 0) and (self.panoId is not None) and (len(str(self.panoId)) == 22):
#     151         # print("panoid: ", self.panoId)
# --> 152         self.jdata = self.getJsonfrmPanoID(panoId=self.panoId, dm=1, saved_path=self.saved_path)
#     153         self.lon = self.jdata['Location']['lng']
#     154         self.lat = self.jdata['Location']['lat']
#
# File D:\Research\StreetView\gsv_pano\pano.py:238, in GSV_pano.getJsonfrmPanoID(self, panoId, dm, saved_path)
#     234 url = url.format(panoId)
#     237 try:
# --> 238     resp = requests.get(url, proxies=None)
#     239     line = resp.text.replace(")]}'\n", "")
#     240     try:
#
# File ~\.conda\envs\geo\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\.conda\envs\geo\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\.conda\envs\geo\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\.conda\envs\geo\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\.conda\envs\geo\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\connectionpool.py:1092, in HTTPSConnectionPool._validate_conn(self, conn)
#    1090 # Force connect early to allow us to validate the connection.
#    1091 if conn.is_closed:
# -> 1092     conn.connect()
#    1094 if not conn.is_verified:
#    1095     warnings.warn(
#    1096         (
#    1097             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1102         InsecureRequestWarning,
#    1103     )
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File ~\.conda\envs\geo\lib\site-packages\urllib3\util\ssl_.py:444, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     442 if ca_certs or ca_cert_dir or ca_cert_data:
#     443     try:
# --> 444         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     445     except OSError as e:
#     446         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
trunk_pairs_df

# %%
all_trunk_gdf
# Out:
#    index   distance  root_center_col  root_bottom_row  azimuth_rad  \
# 0      0  16.328520              222              447    -0.515352
# 1      0  11.061842              878              519     0.620619
#
#    altitude_rad  depth_h_distance  median_wid  median_wid_row  \
# 0     -0.106659         16.235730        33.0             417
# 1     -0.211300         10.815816        32.0             453
#
#    median_row_start_col  median_row_end_col                  panoID  \
# 0                   207                 239  vFu4cCea3kkheGt941HrBA
# 1                   860                 891  Zz5dleaUI9Wt2KJ1IxhLxg
#
#          depth_x        depth_y         pano_x         pano_y  \
# 0  609330.682129  239253.802120  609325.280561  239238.491274
# 1  609341.742968  239246.498196  609334.889684  239238.130736
#
#    pano_heading_deg  thumbnail_heading_deg  trunk_heading_deg  \
# 0         93.959946                  48.96          19.432513
# 1         93.763100                   3.76          39.318844
#
#                                        image_file  azimuth_deg  \
# 0  vFu4cCea3kkheGt941HrBA_0.0_0.0_0_48.96_L45.jpg   -29.527487
# 1   Zz5dleaUI9Wt2KJ1IxhLxg_0.0_0.0_0_3.76_L90.jpg    35.558844
#
#                         geometry   Type
# 0  POINT (609330.682 239253.802)  trunk
# 1  POINT (609341.743 239246.498)  trunk

# %%
trunk_pairs_df
# Out:
#    index   distance  root_center_col  root_bottom_row  azimuth_rad  \
# 0      0  10.249231               38              538    -0.746878
# 1      1   9.870755              870              559     0.610201
#
#    altitude_rad  depth_h_distance  median_wid  median_wid_row  \
# 0     -0.217234         10.008346        45.0             467
# 1     -0.273114          9.504901        22.0             473
#
#    median_row_start_col  median_row_end_col                  panoID  \
# 0                    14                  58  L9Jp_XEhrMmgm35YhruiRQ
# 1                   859                 880  L9Jp_XEhrMmgm35YhruiRQ
#
#          depth_x        depth_y         pano_x         pano_y  \
# 0  608658.094720  239254.141746  608665.849204  239260.469065
# 1  608658.414927  239266.391452  608665.849204  239260.469065
#
#    pano_heading_deg  thumbnail_heading_deg  trunk_heading_deg  \
# 0        183.581512                 273.58         230.787061
# 1        183.581512                 273.58         308.541967
#
#                                         image_file  azimuth_deg  \
# 0  L9Jp_XEhrMmgm35YhruiRQ_0.0_0.0_0_273.58_R90.jpg   -42.792939
# 1  L9Jp_XEhrMmgm35YhruiRQ_0.0_0.0_0_273.58_R90.jpg    34.961967
#
#                         geometry   Type
# 0  POINT (608658.095 239254.142)  trunk
# 1  POINT (608658.415 239266.391)  trunk

# %%
localized_trunk_gdf.explore()

# %%
geometry = gpd.points_from_xy(all_pair_trunk_df['tri_x'], all_pair_trunk_df['tri_y'])
localized_trunk_gdf = gpd.GeoDataFrame(data=all_pair_trunk_df, geometry=geometry).set_crs(local_crs)
localized_trunk_fname = os.path.join(save_dir, "localized_trunks.shp")
localized_trunk_gdf.to_file(localized_trunk_fname)

# %%
def show_image_pair(image_pair, image_dir, camera_dis_thres=20):
    images = []
    basenames = []
    for detect_file in image_pair:
        basename = os.path.basename(detect_file).replace('.pkl.bz2', '.jpg')
        basenames.append(basename[:-4])
        image_fname = os.path.join(image_dir, basename)
        image = cv2.imread(image_fname)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        images.append(image_rgb)

    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 14))

    for idx, image in enumerate(images):
        try:
            # df = trunk_pair_dfs[idx].query(f" depth_h_distance < {camera_dis_thres} ")
            axs[idx].imshow(image)
            # axs[idx].plot(df['root_center_col'], df['root_bottom_row'], 'o', color='red')
            axs[idx].set_title(basenames[idx])
        except:
            pass

# camera_dis_thres = 30
# show_image_pair(image_pair=image_pairs[0], image_dir=image_dir, camera_dis_thres=camera_dis_thres)

# %%
gdf_list = []

for df in [trunk_df, paired_trunk_df]:
    # for trunk initial location from depthmap
    geometry = gpd.points_from_xy(df['depth_x'], df['depth_y'])
    gdf = gpd.GeoDataFrame(data=df, geometry=geometry).set_crs(local_crs)
    gdf['Type'] = 'trunk'
    gdf_list.append(gdf)

    # for pano (camera) location
    geometry = gpd.points_from_xy(df['pano_x'], df['pano_y'])
    gdf = gpd.GeoDataFrame(data=df.iloc[:1], geometry=geometry[:1]).set_crs(local_crs)
    gdf['Type'] = 'camera'
    gdf_list.append(gdf)


# all_gdf = pd.concat(gdf_list)

# all_gdf.explore(column='Type', cmap='seismic', marker_kwds={'radius':5})  # column='type', cmap='seismic',

# %%
# all_gdf.query("type == 'trunk' ").sort_values('x')

near_trunk_thres = 3



all_trunk_gdf = all_gdf.query("Type == 'trunk' ")
all_camera_gdf = all_gdf.query("Type == 'camera' ")

camera_dis_thres = 20

# trunk_pair_df = tri.form_trunk_pairs(all_trunk_gdf, near_thres=3, camera_dis_thres=camera_dis_thres)
# trunk_pair_df

# %% [markdown]
# # Show all images

# %%
def show_paried_trunk(trunk_pair_df, image_dir):
    images = []
    basenames = []
    image_pair = trunk_pair_df.iloc[0:2]['image_file'].to_list()

    for image_file in image_pair:
        basename = os.path.basename(image_file)
        basenames.append(basename)
        image_fname = os.path.join(image_dir, image_file)
        image = cv2.imread(image_fname)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        images.append(image_rgb)


    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 14))

    for idx, image in enumerate(images):

        try:
            df = trunk_pair_df.iloc[idx:idx + 1]
            axs[idx].imshow(image)
            axs[idx].plot(df['root_center_col'], df['root_bottom_row'], 'o', color='red')
            axs[idx].plot(df['root_center_col'], df['median_wid_row'], 'o', color='y')
            axs[idx].set_title(basenames[idx])

        except Exception as e:
            print("Error:", e)
            continue

# show_paried_trunk(trunk_pair_df=trunk_pair_df.iloc[:], image_dir=image_dir)

# %%
trunk_pairs_df

# %%
import matplotlib.pyplot as plt

# %%
a_pair_trunk_df

# %%
trunk_pair_df
all_camera_gdf

# %%
# print(pano.panoID, "heading_dif_deg:", heading_dif_deg)


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(6, 6))

ax.set_ylim(trunk_pair_df['depth_y'].min() - 20, trunk_pair_df['depth_y'].max() + 20)
ax.set_xlim(trunk_pair_df['depth_x'].min() - 20, trunk_pair_df['depth_x'].max() + 20)

for idx, pano in trunk_pair_df.iloc[:2].iterrows():
    tri.draw_yaw_arrow(ax, pano, length=3, width=0.3)
    # break

# %%
trunk_pair_df = tri.griangulate_trunk_location(trunk_pair_df.iloc[:2].copy())
trunk_pair_df

# %%
trunk_pair_df = compute_diameter(trunk_pair_df.iloc[:2].copy())
trunk_pair_df[['h_distance_to_camera', 'median_wid', 'diameter']]

# %%
# pairs_df = form_trunk_pairs(all_trunk_gdf, near_thres=3, camera_dis_thres=15)

# %%
def show_image_pair(image_pair, trunk_pair_dfs, image_dir, camera_dis_thres=20):
    images = []
    basenames = []
    for detect_file in image_pair:
        basename = os.path.basename(detect_file).replace('.pkl.bz2', '.jpg')
        basenames.append(basename[:-4])
        image_fname = os.path.join(image_dir, basename)
        image = cv2.imread(image_fname)
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        images.append(image_rgb)

    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 14))

    for idx, image in enumerate(images):
        try:
            df = trunk_pair_dfs[idx].query(f" depth_h_distance < {camera_dis_thres} ")
            axs[idx].imshow(image)
            axs[idx].plot(df['root_center_col'], df['root_bottom_row'], 'o', color='red')
            axs[idx].set_title(basenames[idx])
        except:
            pass

show_image_pair(image_pair=image_pairs[1], trunk_pair_dfs=[trunk_df, paired_trunk_df], image_dir=image_dir, camera_dis_thres=camera_dis_thres)

# %%
image = cv2.imread(image_fname)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
annotated_image = tri.show_detection_segment(image=image, detections=detection[1])

# %%
pano_meta

# %%
# pano_obj.calculate_xy(pano_meta)

# %%
# Try to use the bottom ten row of depthmap as the distance
root_ground_height = 10 # unit: row

bottom_row = idx_row.max()
top_row = max(idx_row.max() - root_ground_height, 0)
bottom_row, top_row

# %%
len(idx_row)

# %%
root_row_idx = np.where(np.logical_and(top_row < idx_row, idx_row < bottom_row))
root_row_idx

# %%
root_idx

# %%
# the distance of from camera to trunk bottom.
root_idx = row_col_idx[root_row_idx]
depthmap[root_idx[:, 0], root_idx[:, 1]].mean()

# %%
depthmap[root_idx[:, 0], root_idx[:, 1]].max(), depthmap[root_idx[:, 0], root_idx[:, 1]].min()

# %%
(trunk_mask * depthmap)

# %%
plt.hist(depthmap[trunk_mask])
depthmap[trunk_mask].mean()
indices = np.where(trunk_mask > 0)
# print("Indices:", list(zip(indices[0], indices[1])))
# list(zip(indices[0], indices[1]))
# indices[0][0]

# %%
mask = np.zeros_like(depthmap)
highlighted_depthmap = depthmap.copy()
highlighted_depthmap[root_idx[:, 0], root_idx[:, 1]] = 50

plt.imshow(highlighted_depthmap)

# %%
# depthmap = cv2.imread(depthmap_fname)[:, :, 0]
# root_idx
# mask = depthmap[root_idx[:, 0], root_idx[:, 1]]
plt.imshow(depthmap)

# %%
# image = Image.open(depthmap_fname)
# image = Image.open(image_fname)
image = cv2.imread(image_fname)
tri.show_detection_segment(image=image, detections=detection[1])

# %%
plt.imshow(image)

# %%
plt.imshow(masks[0])

# %%
detection[1]
